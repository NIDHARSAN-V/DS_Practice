# %%
# %pip install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../dataset/raw.csv')
display(df)
# Out:
#        patient_id     age   gender   race               marital_status  \
# 0      PAT_00000001    66   Male     Caucasian          Single
# 1      PAT_00000002    55   Male     Caucasian          Single
# 2      PAT_00000003    69   Female   African American   Single
# 3      PAT_00000004    85   Female   Asian              Divorced
# 4      PAT_00000005    53   Female   African American   Married
# ...             ...   ...      ...                ...              ...
# 14995  PAT_00014996    41   Female   Asian              Single
# 14996  PAT_00014997    80   Female   Hispanic           Married
# 14997  PAT_00014998    81   Female   Caucasian          Single
# 14998  PAT_00014999    42   Male     Hispanic           Divorced
# 14999  PAT_00015000    55   Female   Caucasian          Married
#
#         insurance_type   admission_type   admission_source     length_of_stay  \
# 0       Medicare         Elective         Transfer                          2
# ...

# %% [markdown]
# Get Cols

# %%
cols  = df.columns
print(cols)
# Out:
# Index(['patient_id  ', ' age', ' gender', ' race            ',
#        ' marital_status', ' insurance_type', ' admission_type',
#        ' admission_source  ', ' length_of_stay', ' department      ',
#        ' room_type   ', ' num_procedures', ' num_medications', ' has_diabetes',
#        ' has_hypertension', ' has_heart_disease', ' has_copd',
#        ' has_kidney_disease', ' previous_admissions', ' discharge_systolic_bp',
#        ' discharge_diastolic_bp', ' discharge_heart_rate',
#        ' discharge_temperature', ' discharge_o2_saturation',
#        ' hemoglobin_level', ' wbc_count', ' creatinine_level',
#        ' glucose_level', ' discharge_disposition   ', ' follow_up_scheduled',
#        ' medication_adherence_score', ' discharge_date', ' readmitted_30days'],
#       dtype='str')
